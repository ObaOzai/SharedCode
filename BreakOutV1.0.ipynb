# %% [markdown]
# <a href="https://colab.research.google.com/github/ObaOzai/SharedCode/blob/main/BreakOutV1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Breakout ATARI RL Study V 1.0
# ### Juan David Correa http://www.astropema.com May 2025

# %%
#!pip install ale-py==0.8.1 gymnasium==0.28.1 stable-baselines3==2.0.0
#!pip install autorom[accept-rom-license]
#!AutoROM --accept-license
#%pip install gymnasium[atari]
# Out:
# Requirement already satisfied: ale-py==0.8.1 in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.11/dist-packages (0.28.1)
# Requirement already satisfied: stable-baselines3==2.0.0 in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ale-py==0.8.1) (2.0.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py==0.8.1) (6.5.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1) (0.0.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11->stable-baselines3==2.0.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0) (3.0.2)

# %%
# breakout_ppo_full.py
# Fully corrected and complete script for PPO training on Breakout with Gymnasium, ALE and Stable-Baselines3

import os
import time
import logging
from pathlib import Path
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback

# Suppress TensorFlow/CUDA noise if TF is imported under the hood
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Logging setup
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
log = logging.getLogger("BreakoutPPO")

# --- Configuration ---
GAME_ID        = "Breakout"
ENV_ID         = f"ALE/{GAME_ID}-v5"
SEED           = 42
EVAL_SEED      = 5678
NUM_ENVS       = 2
TOTAL_STEPS    = 5_000_000
N_STEPS        = 64
BATCH_SIZE     = 32
N_EPOCHS       = 2
LEARNING_RATE  = 2.5e-4
CLIP_RANGE     = 0.2
ENT_COEF       = 0.01
GAMMA          = 0.99
GAE_LAMBDA     = 0.95
VF_COEF        = 0.5
MAX_GRAD_NORM  = 0.5

# Directory structure
BASE_DIR = Path("./logs") / f"breakout_ppo_{int(time.time())}"
CKPT_DIR = BASE_DIR / "checkpoints"
EVAL_DIR = BASE_DIR / "eval"

# Ensure directories exist
for d in [BASE_DIR, CKPT_DIR, EVAL_DIR]:
    d.mkdir(parents=True, exist_ok=True)
    log.info(f"Ensured directory: {d}")

# Utility to create and seed Gym environment
def make_env(seed: int):
    def _init():
        # Create Atari environment
        env = gym.make(ENV_ID, obs_type='rgb', frameskip=4)
        # Monitor wrapper for ep_rew_mean and ep_len_mean
        env = Monitor(env)
        # Seed and reset
        env.reset(seed=seed)
        return env
    return _init


def main():
    # Create vectorized training environments
    log.info(f"Creating {NUM_ENVS} training environments with seed {SEED}")
    train_env = DummyVecEnv([make_env(SEED + i) for i in range(NUM_ENVS)])
    train_env = VecFrameStack(train_env, n_stack=4)

    # Create evaluation environment
    log.info("Creating evaluation environment")
    eval_env = DummyVecEnv([make_env(EVAL_SEED)])
    eval_env = VecFrameStack(eval_env, n_stack=4)

    # Initialize PPO model
    model = PPO(
        policy="CnnPolicy",
        env=train_env,
        learning_rate=LEARNING_RATE,
        n_steps=N_STEPS,
        batch_size=BATCH_SIZE,
        n_epochs=N_EPOCHS,
        gamma=GAMMA,
        gae_lambda=GAE_LAMBDA,
        clip_range=CLIP_RANGE,
        ent_coef=ENT_COEF,
        vf_coef=VF_COEF,
        max_grad_norm=MAX_GRAD_NORM,
        verbose=1,
        tensorboard_log=str(BASE_DIR),
        device="auto"
    )

    # Callbacks: checkpoints and evaluation
    checkpoint_cb = CheckpointCallback(
        save_freq=100_000,
        save_path=str(CKPT_DIR),
        name_prefix="ppo_breakout"
    )
    eval_cb = EvalCallback(
        eval_env,
        best_model_save_path=str(BASE_DIR / "best"),
        log_path=str(EVAL_DIR),
        eval_freq=50_000,
        n_eval_episodes=5,
        deterministic=True,
        render=False
    )

    # Train
    log.info(f"Starting training for {TOTAL_STEPS:,} timesteps")
    model.learn(
        total_timesteps=TOTAL_STEPS,
        callback=[checkpoint_cb, eval_cb],
        tb_log_name="breakout_ppo",
        reset_num_timesteps=True
    )

    # Save final model
    final_path = BASE_DIR / "ppo_breakout_final"
    model.save(str(final_path))
    log.info(f"Saved final model to {final_path}")

    # Clean up
    train_env.close()
    eval_env.close()

if __name__ == "__main__":
    main()
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to logs/breakout_ppo_1746137934/breakout_ppo_1
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/callbacks.py:403: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x78bbcbc6ab90> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x78bbce918c90>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 0.0221       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 481          |
# |    time_elapsed         | 4280         |
# |    total_timesteps      | 61568        |
# | train/                  |              |
# |    approx_kl            | 0.0021961173 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.9674257    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0136       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.000367     |
# |    value_loss           | 0.013        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 482          |
# |    time_elapsed         | 4288         |
# |    total_timesteps      | 61696        |
# | train/                  |              |
# |    approx_kl            | 0.0013965843 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.9847292    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.019       |
# |    n_updates            | 962          |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 0.00421      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 483          |
# |    time_elapsed         | 4298         |
# |    total_timesteps      | 61824        |
# | train/                  |              |
# |    approx_kl            | 0.0009289924 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.804211     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0204      |
# |    n_updates            | 964          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 0.0111       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 484          |
# |    time_elapsed         | 4307         |
# |    total_timesteps      | 61952        |
# | train/                  |              |
# |    approx_kl            | 0.0032049986 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.96867394   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0526      |
# |    n_updates            | 966          |
# |    policy_gradient_loss | -0.00484     |
# |    value_loss           | 0.00568      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 485          |
# |    time_elapsed         | 4316         |
# |    total_timesteps      | 62080        |
# | train/                  |              |
# |    approx_kl            | 0.0019397456 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.90837204   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.014       |
# |    n_updates            | 968          |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 0.00787      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 486          |
# |    time_elapsed         | 4325         |
# |    total_timesteps      | 62208        |
# | train/                  |              |
# |    approx_kl            | 0.0031873188 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0.9866818    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0164      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 0.00625      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 487          |
# |    time_elapsed         | 4334         |
# |    total_timesteps      | 62336        |
# | train/                  |              |
# |    approx_kl            | 0.0033576554 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.912274     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00521     |
# |    n_updates            | 972          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 0.00955      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 488          |
# |    time_elapsed         | 4343         |
# |    total_timesteps      | 62464        |
# | train/                  |              |
# |    approx_kl            | 0.0007685437 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.977027     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00157     |
# |    n_updates            | 974          |
# |    policy_gradient_loss | 0.00088      |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 489          |
# |    time_elapsed         | 4352         |
# |    total_timesteps      | 62592        |
# | train/                  |              |
# |    approx_kl            | 0.0037947497 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.735       |
# |    explained_variance   | 0.9820315    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0294      |
# |    n_updates            | 976          |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 0.00553      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 490          |
# |    time_elapsed         | 4360         |
# |    total_timesteps      | 62720        |
# | train/                  |              |
# |    approx_kl            | 0.0029672869 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.8686542    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0141       |
# |    n_updates            | 978          |
# |    policy_gradient_loss | -6.26e-05    |
# |    value_loss           | 0.0135       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 491          |
# |    time_elapsed         | 4370         |
# |    total_timesteps      | 62848        |
# | train/                  |              |
# |    approx_kl            | 0.0016173013 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.9904361    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0337      |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 0.00407      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 492          |
# |    time_elapsed         | 4379         |
# |    total_timesteps      | 62976        |
# | train/                  |              |
# |    approx_kl            | 0.0015388825 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.9008633    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0346      |
# |    n_updates            | 982          |
# |    policy_gradient_loss | -0.00873     |
# |    value_loss           | 0.0151       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 493         |
# |    time_elapsed         | 4387        |
# |    total_timesteps      | 63104       |
# | train/                  |             |
# |    approx_kl            | 0.011215778 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.97550803  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0487     |
# |    n_updates            | 984         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.00872     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 494          |
# |    time_elapsed         | 4397         |
# |    total_timesteps      | 63232        |
# | train/                  |              |
# |    approx_kl            | 0.0043347557 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | 0.9818259    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0331      |
# |    n_updates            | 986          |
# |    policy_gradient_loss | -0.00928     |
# |    value_loss           | 0.00832      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 495         |
# |    time_elapsed         | 4406        |
# |    total_timesteps      | 63360       |
# | train/                  |             |
# |    approx_kl            | 0.002086429 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.85080075  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00829    |
# |    n_updates            | 988         |
# |    policy_gradient_loss | 0.00119     |
# |    value_loss           | 0.0194      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 226          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 496          |
# |    time_elapsed         | 4415         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0010679397 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.91799635   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0193      |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 0.0101       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.54         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 497          |
# |    time_elapsed         | 4424         |
# |    total_timesteps      | 63616        |
# | train/                  |              |
# |    approx_kl            | 0.0036951848 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.9813034    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0277      |
# |    n_updates            | 992          |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 0.00837      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | 2.54       |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 498        |
# |    time_elapsed         | 4433       |
# |    total_timesteps      | 63744      |
# | train/                  |            |
# |    approx_kl            | 0.00768775 |
# |    clip_fraction        | 0.0547     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.92592    |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0447    |
# |    n_updates            | 994        |
# |    policy_gradient_loss | -0.00923   |
# |    value_loss           | 0.0199     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.54         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 499          |
# |    time_elapsed         | 4442         |
# |    total_timesteps      | 63872        |
# | train/                  |              |
# |    approx_kl            | 0.0006791437 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.956       |
# |    explained_variance   | 0.98276925   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0192      |
# |    n_updates            | 996          |
# |    policy_gradient_loss | 0.000543     |
# |    value_loss           | 0.00387      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 500          |
# |    time_elapsed         | 4451         |
# |    total_timesteps      | 64000        |
# | train/                  |              |
# |    approx_kl            | 0.0038153213 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.6593664    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0257      |
# |    n_updates            | 998          |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 0.00732      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 501          |
# |    time_elapsed         | 4460         |
# |    total_timesteps      | 64128        |
# | train/                  |              |
# |    approx_kl            | 0.0006587934 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.9399152    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00033     |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 0.0162       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 502          |
# |    time_elapsed         | 4469         |
# |    total_timesteps      | 64256        |
# | train/                  |              |
# |    approx_kl            | 0.0066759973 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.9736523    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0229       |
# |    n_updates            | 1002         |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.0141       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 503          |
# |    time_elapsed         | 4479         |
# |    total_timesteps      | 64384        |
# | train/                  |              |
# |    approx_kl            | 0.0055826725 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.8402708    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0186      |
# |    n_updates            | 1004         |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 504          |
# |    time_elapsed         | 4487         |
# |    total_timesteps      | 64512        |
# | train/                  |              |
# |    approx_kl            | 0.0037337174 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.9889602    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00824      |
# |    n_updates            | 1006         |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 0.00612      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 2.58        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 505         |
# |    time_elapsed         | 4497        |
# |    total_timesteps      | 64640       |
# | train/                  |             |
# |    approx_kl            | 0.004983151 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.8247478   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0121     |
# |    n_updates            | 1008        |
# |    policy_gradient_loss | -0.00686    |
# |    value_loss           | 0.0251      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 506          |
# |    time_elapsed         | 4506         |
# |    total_timesteps      | 64768        |
# | train/                  |              |
# |    approx_kl            | 0.0036381655 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.89396816   |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0138       |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 0.0354       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 507          |
# |    time_elapsed         | 4514         |
# |    total_timesteps      | 64896        |
# | train/                  |              |
# |    approx_kl            | 0.0006667264 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.726       |
# |    explained_variance   | 0.9593289    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0205      |
# |    n_updates            | 1012         |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 0.00539      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 508          |
# |    time_elapsed         | 4524         |
# |    total_timesteps      | 65024        |
# | train/                  |              |
# |    approx_kl            | 0.0017147474 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.9114958    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00313      |
# |    n_updates            | 1014         |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 228           |
# |    ep_rew_mean          | 2.57          |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 509           |
# |    time_elapsed         | 4533          |
# |    total_timesteps      | 65152         |
# | train/                  |               |
# |    approx_kl            | 0.00041232258 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.669        |
# |    explained_variance   | 0.9577251     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.000735     |
# |    n_updates            | 1016          |
# |    policy_gradient_loss | 0.000587      |
# |    value_loss           | 0.0167        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.57        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 510         |
# |    time_elapsed         | 4542        |
# |    total_timesteps      | 65280       |
# | train/                  |             |
# |    approx_kl            | 0.008865343 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.99193704  |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0579      |
# |    n_updates            | 1018        |
# |    policy_gradient_loss | 0.00218     |
# |    value_loss           | 0.00626     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.56        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 511         |
# |    time_elapsed         | 4551        |
# |    total_timesteps      | 65408       |
# | train/                  |             |
# |    approx_kl            | 0.002166403 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -2.4990978  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0181     |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 0.00299     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 512          |
# |    time_elapsed         | 4561         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0061283535 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.887716     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00869     |
# |    n_updates            | 1022         |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 0.0141       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.56        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 513         |
# |    time_elapsed         | 4569        |
# |    total_timesteps      | 65664       |
# | train/                  |             |
# |    approx_kl            | 0.026177578 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.95367736  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0223     |
# |    n_updates            | 1024        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.013       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | 2.54       |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 514        |
# |    time_elapsed         | 4579       |
# |    total_timesteps      | 65792      |
# | train/                  |            |
# |    approx_kl            | 0.00153213 |
# |    clip_fraction        | 0.0117     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.406     |
# |    explained_variance   | 0.9877384  |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0046    |
# |    n_updates            | 1026       |
# |    policy_gradient_loss | -0.00285   |
# |    value_loss           | 0.00602    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | 2.53       |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 515        |
# |    time_elapsed         | 4588       |
# |    total_timesteps      | 65920      |
# | train/                  |            |
# |    approx_kl            | 0.01399713 |
# |    clip_fraction        | 0.082      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.703     |
# |    explained_variance   | 0.95101523 |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0494    |
# |    n_updates            | 1028       |
# |    policy_gradient_loss | -0.0188    |
# |    value_loss           | 0.0168     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 516          |
# |    time_elapsed         | 4596         |
# |    total_timesteps      | 66048        |
# | train/                  |              |
# |    approx_kl            | 0.0047777663 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.9785539    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0151       |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | 0.00468      |
# |    value_loss           | 0.00719      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 517          |
# |    time_elapsed         | 4606         |
# |    total_timesteps      | 66176        |
# | train/                  |              |
# |    approx_kl            | 0.0013289228 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.827       |
# |    explained_variance   | 0.8909296    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0187      |
# |    n_updates            | 1032         |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 0.0205       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.53         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 518          |
# |    time_elapsed         | 4615         |
# |    total_timesteps      | 66304        |
# | train/                  |              |
# |    approx_kl            | 0.0040862425 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 0.67086506   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0105      |
# |    n_updates            | 1034         |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 0.0158       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.56        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 519         |
# |    time_elapsed         | 4624        |
# |    total_timesteps      | 66432       |
# | train/                  |             |
# |    approx_kl            | 0.001291737 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.90191185  |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.012       |
# |    n_updates            | 1036        |
# |    policy_gradient_loss | 0.00136     |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 520          |
# |    time_elapsed         | 4633         |
# |    total_timesteps      | 66560        |
# | train/                  |              |
# |    approx_kl            | 0.0032419069 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.733       |
# |    explained_variance   | 0.9856529    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0158      |
# |    n_updates            | 1038         |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 0.00779      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.56        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 521         |
# |    time_elapsed         | 4642        |
# |    total_timesteps      | 66688       |
# | train/                  |             |
# |    approx_kl            | 0.009975603 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.9432968   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.028       |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | 0.00537     |
# |    value_loss           | 0.00638     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.56         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 522          |
# |    time_elapsed         | 4651         |
# |    total_timesteps      | 66816        |
# | train/                  |              |
# |    approx_kl            | 0.0004403661 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.77303743   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00421     |
# |    n_updates            | 1042         |
# |    policy_gradient_loss | 1.56e-05     |
# |    value_loss           | 0.0218       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 523          |
# |    time_elapsed         | 4660         |
# |    total_timesteps      | 66944        |
# | train/                  |              |
# |    approx_kl            | 0.0006914106 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.9492133    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00869     |
# |    n_updates            | 1044         |
# |    policy_gradient_loss | -0.000671    |
# |    value_loss           | 0.0122       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 228           |
# |    ep_rew_mean          | 2.57          |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 524           |
# |    time_elapsed         | 4669          |
# |    total_timesteps      | 67072         |
# | train/                  |               |
# |    approx_kl            | 0.00022257166 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.849        |
# |    explained_variance   | 0.9728476     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00326      |
# |    n_updates            | 1046          |
# |    policy_gradient_loss | 5.89e-05      |
# |    value_loss           | 0.00926       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 228           |
# |    ep_rew_mean          | 2.57          |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 525           |
# |    time_elapsed         | 4678          |
# |    total_timesteps      | 67200         |
# | train/                  |               |
# |    approx_kl            | 0.00030132942 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.825        |
# |    explained_variance   | 0.95814073    |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.00544      |
# |    n_updates            | 1048          |
# |    policy_gradient_loss | -0.000382     |
# |    value_loss           | 0.00632       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 526          |
# |    time_elapsed         | 4688         |
# |    total_timesteps      | 67328        |
# | train/                  |              |
# |    approx_kl            | 0.0009137322 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.9544879    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0178      |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 0.00908      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 527          |
# |    time_elapsed         | 4696         |
# |    total_timesteps      | 67456        |
# | train/                  |              |
# |    approx_kl            | 0.0021794145 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.8965965    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000216     |
# |    n_updates            | 1052         |
# |    policy_gradient_loss | 5.98e-05     |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 2.58         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 528          |
# |    time_elapsed         | 4706         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0015336415 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.9761242    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00812     |
# |    n_updates            | 1054         |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 0.00948      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 228          |
# |    ep_rew_mean          | 2.57         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 529          |
# |    time_elapsed         | 4715         |
# |    total_timesteps      | 67712        |
# | train/                  |              |
# |    approx_kl            | 0.0019033579 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.98568267   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0168      |
# |    n_updates            | 1056         |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 2.57        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 530         |
# |    time_elapsed         | 4724        |
# |    total_timesteps      | 67840       |
# | train/                  |             |
# |    approx_kl            | 0.006772199 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.9704202   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00943    |
# |    n_updates            | 1058        |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 0.00658     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 2.54        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 531         |
# |    time_elapsed         | 4733        |
# |    total_timesteps      | 67968       |
# | train/                  |             |
# |    approx_kl            | 0.001202248 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.28530467  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00183    |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | 2.66e-05    |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 227           |
# |    ep_rew_mean          | 2.54          |
# | time/                   |               |
# |    fps                  | 14            |
# |    iterations           | 532           |
# |    time_elapsed         | 4742          |
# |    total_timesteps      | 68096         |
# | train/                  |               |
# |    approx_kl            | 0.00038600387 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.871        |
# |    explained_variance   | 0.96611845    |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0202       |
# |    n_updates            | 1062          |
# |    policy_gradient_loss | -0.00201      |
# |    value_loss           | 0.00966       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 227          |
# |    ep_rew_mean          | 2.54         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 533          |
# |    time_elapsed         | 4751         |
# |    total_timesteps      | 68224        |
# | train/                  |              |
# |    approx_kl            | 0.0012521613 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.769       |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 2.62         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 701          |
# |    time_elapsed         | 6284         |
# |    total_timesteps      | 89728        |
# | train/                  |              |
# |    approx_kl            | 0.0034347842 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.97970986   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.036       |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 0.00715      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 702         |
# |    time_elapsed         | 6293        |
# |    total_timesteps      | 89856       |
# | train/                  |             |
# |    approx_kl            | 0.007601767 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.9605978   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0111      |
# |    n_updates            | 1402        |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 703         |
# |    time_elapsed         | 6302        |
# |    total_timesteps      | 89984       |
# | train/                  |             |
# |    approx_kl            | 0.016420474 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.98561734  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0897     |
# |    n_updates            | 1404        |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 0.00348     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 2.63        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 704         |
# |    time_elapsed         | 6311        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011322163 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.70881295  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0398     |
# |    n_updates            | 1406        |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 0.0141      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 705         |
# |    time_elapsed         | 6320        |
# |    total_timesteps      | 90240       |
# | train/                  |             |
# |    approx_kl            | 0.020335175 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.9506189   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00384    |
# |    n_updates            | 1408        |
# |    policy_gradient_loss | 0.00231     |
# |    value_loss           | 0.00862     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 706         |
# |    time_elapsed         | 6329        |
# |    total_timesteps      | 90368       |
# | train/                  |             |
# |    approx_kl            | 0.005152614 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.2979595   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0261     |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00526    |
# |    value_loss           | 0.00765     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.61        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 707         |
# |    time_elapsed         | 6339        |
# |    total_timesteps      | 90496       |
# | train/                  |             |
# |    approx_kl            | 0.008089572 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.8523034   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0131     |
# |    n_updates            | 1412        |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 0.00767     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 2.6          |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 708          |
# |    time_elapsed         | 6347         |
# |    total_timesteps      | 90624        |
# | train/                  |              |
# |    approx_kl            | 0.0014163442 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.878       |
# |    explained_variance   | 0.85661834   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0108      |
# |    n_updates            | 1414         |
# |    policy_gradient_loss | -0.000657    |
# |    value_loss           | 0.0228       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 2.6         |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 709         |
# |    time_elapsed         | 6357        |
# |    total_timesteps      | 90752       |
# | train/                  |             |
# |    approx_kl            | 0.013285967 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.94301206  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0184     |
# |    n_updates            | 1416        |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.00435     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 2.6         |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 710         |
# |    time_elapsed         | 6366        |
# |    total_timesteps      | 90880       |
# | train/                  |             |
# |    approx_kl            | 0.009024367 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.9925367   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0197     |
# |    n_updates            | 1418        |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 0.00408     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 231          |
# |    ep_rew_mean          | 2.6          |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 711          |
# |    time_elapsed         | 6375         |
# |    total_timesteps      | 91008        |
# | train/                  |              |
# |    approx_kl            | 0.0024497448 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.8727535    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0301      |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 0.0128       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 2.63        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 712         |
# |    time_elapsed         | 6384        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.028735504 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.98363703  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0389     |
# |    n_updates            | 1422        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.00684     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 2.62         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 713          |
# |    time_elapsed         | 6394         |
# |    total_timesteps      | 91264        |
# | train/                  |              |
# |    approx_kl            | 0.0027087778 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | 0.9776743    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00925      |
# |    n_updates            | 1424         |
# |    policy_gradient_loss | 0.00247      |
# |    value_loss           | 0.00854      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 714         |
# |    time_elapsed         | 6402        |
# |    total_timesteps      | 91392       |
# | train/                  |             |
# |    approx_kl            | 0.007898204 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.98635715  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00912    |
# |    n_updates            | 1426        |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 2.62         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 715          |
# |    time_elapsed         | 6411         |
# |    total_timesteps      | 91520        |
# | train/                  |              |
# |    approx_kl            | 0.0025139959 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.9893776    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00636     |
# |    n_updates            | 1428         |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 0.00936      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | 2.62         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 716          |
# |    time_elapsed         | 6421         |
# |    total_timesteps      | 91648        |
# | train/                  |              |
# |    approx_kl            | 0.0017628348 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.98480326   |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.011       |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.000937    |
# |    value_loss           | 0.00342      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | 2.62        |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 717         |
# |    time_elapsed         | 6429        |
# |    total_timesteps      | 91776       |
# | train/                  |             |
# |    approx_kl            | 0.008615815 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.94265395  |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0298     |
# |    n_updates            | 1432        |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | 2.63         |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 718          |
# |    time_elapsed         | 6439         |
# |    total_timesteps      | 91904        |
# | train/                  |              |
# |    approx_kl            | 0.0033816108 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.07606602  |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0135       |
# |    n_updates            | 1434         |
# |    policy_gradient_loss | -0.00609     |
# |    value_loss           | 0.0635       |
# ------------------------------------------
